# %%
import pandas as pd
import math

df = pd.read_json('./galaxy_1day.json', orient='records')

# %%
df.columns
# Out:
# Index(['id64', 'name', 'coords', 'allegiance', 'government', 'primaryEconomy',
#        'secondaryEconomy', 'security', 'population', 'bodyCount', 'date',
#        'bodies', 'stations', 'controllingFaction', 'factions',
#        'controllingPower', 'powerState', 'powerStateControlProgress',
#        'powerStateReinforcement', 'powerStateUndermining', 'powers',
#        'timestamps', 'powerConflictProgress'],
#       dtype='object')

# %%
df.size
# Out:
# 3499910

# %%
with_bodies = df[ df['bodyCount'] > 0]

# %%
with_bodies.size
# Out:
# 1239585

# %%
populated = with_bodies[with_bodies['population'] > 0 ]

# %%
unpopulated = with_bodies[with_bodies['population'] <= 0]

# %%
populated.size

# %%
def distance(origin):
    return lambda p : math.sqrt((origin.x - p.x)**2 + (origin.y - p.y)**2 + (origin.z - p.z)**2)

def adjecent_systems(origin):
    cp = populated.copy()
    with_dist = cp.assign(dist = math.sqrt((origin['coords.x'] - cp['coords.x'])**2 + (origin['coords.y'] - cp['coords.y'])**2 + (origin['coords.z'] - cp['coords.z'])**2))    
    with_dist = with_dist[with_dist['dist'] <= 15]
    return with_dist

# %%
with_adjecent = unpopulated.assign(adjecent = lambda x: adjecent_systems(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2s/2rxvykr542373ry02yl51q740000gn/T/ipykernel_12826/3599229871.py in ?()
# ----> 1 with_adjecent = unpopulated.assign(adjecent = lambda x: adjecent_systems(x))
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, **kwargs)
#    5235         """
#    5236         data = self.copy(deep=None)
#    5237
#    5238         for k, v in kwargs.items():
# -> 5239             data[k] = com.apply_if_callable(v, data)
#    5240         return data
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/common.py in ?(maybe_callable, obj, **kwargs)
#     380     obj : NDFrame
#     381     **kwargs
#     382     """
#     383     if callable(maybe_callable):
# --> 384         return maybe_callable(obj, **kwargs)
#     385
#     386     return maybe_callable
#
# ...

# %%
with_adjecent = with_adjecent[with_adjecent['adjecent'].apply(len) > 0]

# %%
with_adjecent['adjecent']

# %%
with_adjecent.columns
